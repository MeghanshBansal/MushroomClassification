# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import sklearn

# %%
df = pd.read_csv("mushrooms.csv")
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
#  13  stalk-surface-below-ring  8124 non-null   object
#  14  stalk-color-above-ring    8124 non-null   object
#  15  stalk-color-below-ring    8124 non-null   object
#  16  veil-type                 8124 non-null   object
#  17  veil-color                8124 non-null   object
#  18  ring-number               8124 non-null   object
#  19  ring-type                 8124 non-null   object
#  20  spore-print-color         8124 non-null   object
#  21  population                8124 non-null   object
#  22  habitat                   8124 non-null   object
# dtypes: object(23)
# memory usage: 1.4+ MB

# %% [markdown]
# ## Here, class feature is our target and all other are input features
# ### p: Poisonous, e: Edible

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['class'] = encoder.fit_transform(df['class'])
print("Encoding: ", dict(zip(encoder.classes_, encoder.transform(encoder.classes_))))
# Out:
# Encoding:  {'e': 0, 'p': 1}

# %%
X, y = df.drop('class', axis=1), df['class']
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=41, shuffle=True)

# %%
x_train.head()
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 7447         k           y         e       f    s               f
# 4108         f           f         g       f    f               f
# 1299         f           s         w       f    n               f
# 4196         x           y         n       f    y               f
# 6361         x           y         e       f    y               f
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 7447            c         n          b           t  ...
# 4108            c         b          p           e  ...
# 1299            w         b          n           t  ...
# 4196            c         n          b           t  ...
# 6361            c         n          b           t  ...
#
#      stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 7447                        k                      w                      w
# 4108                        k                      b                      n
# 1299                        s                      w                      w
# 4196                        k                      p                      p
# 6361                        s                      p                      p
#
#      veil-type veil-color ring-number ring-type spore-print-color population  \
# 7447         p          w           o         e                 w          v
# 4108         p          w           o         l                 h          v
# 1299         p          w           o         e                 n          a
# 4196         p          w           o         e                 w          v
# 6361         p          w           o         e                 w          v
#
#      habitat
# 7447       p
# 4108       g
# 1299       g
# 4196       d
# 6361       d
#
# [5 rows x 22 columns]

# %%
x_train.describe()
# Out:
#        cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count       5686        5686      5686    5686  5686            5686
# unique         6           4        10       2     9               2
# top            x           y         n       f     n               f
# freq        2578        2280      1617    3315  2474            5549
#
#        gill-spacing gill-size gill-color stalk-shape  ...  \
# count          5686      5686       5686        5686  ...
# unique            2         2         12           2  ...
# top               c         b          b           t  ...
# freq           4778      3919       1225        3258  ...
#
#        stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# count                      5686                   5686                   5686
# unique                        4                      9                      9
# top                           s                      w                      w
# freq                       3466                   3114                   3033
#
#        veil-type veil-color ring-number ring-type spore-print-color  \
# count       5686       5686        5686      5686              5686
# unique         1          4           3         5                 9
# top            p          w           o         p                 w
# freq        5686       5558        5255      2774              1674
#
#        population habitat
# count        5686    5686
# unique          6       7
# top             v       d
# freq         2832    2229
#
# [4 rows x 22 columns]

# %% [markdown]
# ## Checking for NULL values

# %%
sns.heatmap(x_train.isnull())
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### There are no null values in the data

# %%
sns.countplot(y_train)
# Out:
# <AxesSubplot: ylabel='count'>

# %% [markdown]
# ### Our data is almost equally distributed in two classes

# %% [markdown]
# ## Converting our categorical features into numerical features

# %%
from sklearn.preprocessing import LabelEncoder
for column in x_train.columns:
    encoder = LabelEncoder()
    encoder.fit(x_train[column])
    x_train[column] = encoder.transform(x_train[column])
    x_test[column] = encoder.transform(x_test[column])

# %%
x_train.head()
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 7447          3            3          2        0     7                1
# 4108          2            0          3        0     2                1
# 1299          2            2          8        0     5                1
# 4196          5            3          4        0     8                1
# 6361          5            3          2        0     8                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 7447             0          1           0            1  ...
# 4108             0          0           7            0  ...
# 1299             1          0           5            1  ...
# 4196             0          1           0            1  ...
# 6361             0          1           0            1  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 7447                         1                       7
# 4108                         1                       0
# 1299                         2                       7
# 4196                         1                       6
# 6361                         2                       6
#
#       stalk-color-below-ring  veil-type  veil-color  ring-number  ring-type  \
# 7447                       7          0           2            1          0
# 4108                       4          0           2            1          2
# 1299                       7          0           2            1          0
# 4196                       6          0           2            1          0
# 6361                       6          0           2            1          0
#
#       spore-print-color  population  habitat
# 7447                  7           4        4
# 4108                  1           4        1
# 1299                  3           0        1
# 4196                  7           4        0
# 6361                  7           4        0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Removing any constant or low variation feature from our data

# %%
from sklearn.feature_selection import VarianceThreshold
thresh = VarianceThreshold(0.1) #Removing features with variance less than 10%
thresh.fit(x_train)
thresh.get_support()
# Out:
# array([ True,  True,  True,  True,  True, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False, False, False,
#         True,  True,  True,  True])

# %%
x_test = x_test[x_train.columns[thresh.get_support()]]
x_train = x_train[x_train.columns[thresh.get_support()]]

# %%
x_train.head()
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-spacing  \
# 7447          3            3          2        0     7             0
# 4108          2            0          3        0     2             0
# 1299          2            2          8        0     5             1
# 4196          5            3          4        0     8             0
# 6361          5            3          2        0     8             0
#
#       gill-size  gill-color  stalk-shape  stalk-root  \
# 7447          1           0            1           0
# 4108          0           7            0           1
# 1299          0           5            1           3
# 4196          1           0            1           0
# 6361          1           0            1           0
#
#       stalk-surface-above-ring  stalk-surface-below-ring  \
# 7447                         1                         1
# 4108                         1                         1
# 1299                         2                         2
# 4196                         1                         1
# 6361                         2                         2
#
#       stalk-color-above-ring  stalk-color-below-ring  ring-type  \
# 7447                       7                       7          0
# 4108                       0                       4          2
# 1299                       7                       7          0
# 4196                       6                       6          0
# 6361                       6                       6          0
#
#       spore-print-color  population  habitat
# 7447                  7           4        4
# 4108                  1           4        1
# 1299                  3           0        1
# 4196                  7           4        0
# 6361                  7           4        0

# %% [markdown]
# ## Exploring Correlation between features

# %%
x_train.corr()
# Out:
#                           cap-shape  cap-surface  cap-color   bruises  \
# cap-shape                  1.000000    -0.056279  -0.042806 -0.040624
# cap-surface               -0.056279     1.000000  -0.021192  0.060704
# cap-color                 -0.042806    -0.021192   1.000000 -0.000174
# bruises                   -0.040624     0.060704  -0.000174  1.000000
# odor                      -0.020341     0.044482  -0.398873 -0.062914
# gill-spacing               0.027082    -0.279666   0.140134 -0.300515
# gill-size                  0.060050     0.203675  -0.170789 -0.379823
# gill-color                -0.009355    -0.161559   0.091467  0.539523
# stalk-shape                0.067390    -0.018866  -0.464080  0.099116
# stalk-root                 0.033585    -0.130801   0.317718  0.242589
# stalk-surface-above-ring  -0.029427     0.087267  -0.063808  0.474442
# stalk-surface-below-ring  -0.036135     0.092741  -0.045242  0.459968
# stalk-color-above-ring    -0.025880     0.066538   0.016440  0.071217
# stalk-color-below-ring    -0.020674     0.072473   0.010310  0.085880
# ring-type                 -0.028407    -0.110602   0.171817  0.698268
# spore-print-color         -0.072159     0.229990  -0.300560 -0.290048
# population                 0.054795     0.021793  -0.145374  0.086958
# habitat                   -0.042394     0.164586   0.032583 -0.085781
#
#                               odor  gill-spacing  gill-size  gill-color  \
# cap-shape                -0.020341      0.027082   0.060050   -0.009355
# cap-surface               0.044482     -0.279666   0.203675   -0.161559
# cap-color                -0.398873      0.140134  -0.170789    0.091467
# bruises                  -0.062914     -0.300515  -0.379823    0.539523
# odor                      1.000000      0.054673   0.311932   -0.145757
# gill-spacing              0.054673      1.000000  -0.110141    0.088909
# gill-size                 0.311932     -0.110141   1.000000   -0.523539
# gill-color               -0.145757      0.088909  -0.523539    1.000000
# stalk-shape               0.469712      0.081267   0.214751   -0.179197
# stalk-root               -0.211808      0.357036  -0.353342    0.321465
# stalk-surface-above-ring  0.112715     -0.230287   0.052712    0.233575
# stalk-surface-below-ring  0.063371     -0.213485   0.010872    0.256457
# stalk-color-above-ring    0.171021      0.272848   0.297174   -0.060736
# stalk-color-below-ring    0.167237      0.252691   0.277081   -0.079596
# ring-type                -0.286737     -0.195759  -0.465751    0.632464
# spore-print-color         0.473491      0.036142   0.629882   -0.427752
# population               -0.032229     -0.529477   0.147558   -0.026929
# habitat                  -0.014416     -0.154516   0.172406   -0.216049
#
#                           stalk-shape  stalk-root  stalk-surface-above-ring  \
# cap-shape                    0.067390    0.033585                 -0.029427
# cap-surface                 -0.018866   -0.130801                  0.087267
# cap-color                   -0.464080    0.317718                 -0.063808
# bruises                      0.099116    0.242589                  0.474442
# odor                         0.469712   -0.211808                  0.112715
# gill-spacing                 0.081267    0.357036                 -0.230287
# gill-size                    0.214751   -0.353342                  0.052712
# gill-color                  -0.179197    0.321465                  0.233575
# stalk-shape                  1.000000   -0.167088                  0.018700
# stalk-root                  -0.167088    1.000000                 -0.036054
# stalk-surface-above-ring     0.018700   -0.036054                  1.000000
# stalk-surface-below-ring    -0.026878    0.088123                  0.428975
# stalk-color-above-ring       0.216351    0.156575                  0.122662
# stalk-color-below-ring       0.233345    0.161438                  0.135956
# ring-type                   -0.288441    0.215114                  0.403222
# spore-print-color            0.263310   -0.545388                  0.094365
# population                   0.089423   -0.316461                  0.098895
# habitat                     -0.271138   -0.008280                 -0.042976
#
#                           stalk-surface-below-ring  stalk-color-above-ring  \
# cap-shape                                -0.036135               -0.025880
# cap-surface                               0.092741                0.066538
# cap-color                                -0.045242                0.016440
# bruises                                   0.459968                0.071217
# odor                                      0.063371                0.171021
# gill-spacing                             -0.213485                0.272848
# gill-size                                 0.010872                0.297174
# gill-color                                0.256457               -0.060736
# stalk-shape                              -0.026878                0.216351
# stalk-root                                0.088123                0.156575
# stalk-surface-above-ring                  0.428975                0.122662
# stalk-surface-below-ring                  1.000000                0.104678
# stalk-color-above-ring                    0.104678                1.000000
# stalk-color-below-ring                    0.109916                0.482901
# ring-type                                 0.389692               -0.054915
# spore-print-color                         0.128047                0.271573
# population                                0.052536               -0.241562
# habitat                                  -0.042016                0.049112
#
#                           stalk-color-below-ring  ring-type  \
# cap-shape                              -0.020674  -0.028407
# cap-surface                             0.072473  -0.110602
# cap-color                               0.010310   0.171817
# bruises                                 0.085880   0.698268
# odor                                    0.167237  -0.286737
# gill-spacing                            0.252691  -0.195759
# gill-size                               0.277081  -0.465751
# gill-color                             -0.079596   0.632464
# stalk-shape                             0.233345  -0.288441
# stalk-root                              0.161438   0.215114
# stalk-surface-above-ring                0.135956   0.403222
# stalk-surface-below-ring                0.109916   0.389692
# stalk-color-above-ring                  0.482901  -0.054915
# stalk-color-below-ring                  1.000000  -0.034499
# ring-type                              -0.034499   1.000000
# spore-print-color                       0.254080  -0.492815
# population                             -0.247833   0.215791
# habitat                                 0.044609  -0.221230
#
#                           spore-print-color  population   habitat
# cap-shape                         -0.072159    0.054795 -0.042394
# cap-surface                        0.229990    0.021793  0.164586
# cap-color                         -0.300560   -0.145374  0.032583
# bruises                           -0.290048    0.086958 -0.085781
# odor                               0.473491   -0.032229 -0.014416
# gill-spacing                       0.036142   -0.529477 -0.154516
# gill-size                          0.629882    0.147558  0.172406
# gill-color                        -0.427752   -0.026929 -0.216049
# stalk-shape                        0.263310    0.089423 -0.271138
# stalk-root                        -0.545388   -0.316461 -0.008280
# stalk-surface-above-ring           0.094365    0.098895 -0.042976
# stalk-surface-below-ring           0.128047    0.052536 -0.042016
# stalk-color-above-ring             0.271573   -0.241562  0.049112
# stalk-color-below-ring             0.254080   -0.247833  0.044609
# ring-type                         -0.492815    0.215791 -0.221230
# spore-print-color                  1.000000   -0.124844  0.199772
# population                        -0.124844    1.000000 -0.177068
# habitat                            0.199772   -0.177068  1.000000

# %%
plt.figure(figsize=(16, 12))
sns.heatmap(x_train.corr(), annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### There are no feature with very high correlation

# %%
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest
selectkbest = SelectKBest(score_func=mutual_info_classif, k=17)
selectkbest.fit(x_train, y_train)
x_test = x_test[x_train.columns[selectkbest.get_support()]]
x_train = x_train[x_train.columns[selectkbest.get_support()]]
x_train.head()
# Out:
#       cap-shape  cap-surface  bruises  odor  gill-spacing  gill-size  \
# 7447          3            3        0     7             0          1
# 4108          2            0        0     2             0          0
# 1299          2            2        0     5             1          0
# 4196          5            3        0     8             0          1
# 6361          5            3        0     8             0          1
#
#       gill-color  stalk-shape  stalk-root  stalk-surface-above-ring  \
# 7447           0            1           0                         1
# 4108           7            0           1                         1
# 1299           5            1           3                         2
# 4196           0            1           0                         1
# 6361           0            1           0                         2
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 7447                         1                       7
# 4108                         1                       0
# 1299                         2                       7
# 4196                         1                       6
# 6361                         2                       6
#
#       stalk-color-below-ring  ring-type  spore-print-color  population  \
# 7447                       7          0                  7           4
# 4108                       4          2                  1           4
# 1299                       7          0                  3           0
# 4196                       6          0                  7           4
# 6361                       6          0                  7           4
#
#       habitat
# 7447        4
# 4108        1
# 1299        1
# 4196        0
# 6361        0

# %% [markdown]
# # Models

# %% [markdown]
# ## Logistic Regerssion

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train, y_train)
print("Training accuracy score: ", lr.score(x_train, y_train))
print("Testing accuracy score: ", lr.score(x_test, y_test))
# Out:
# Training accuracy score:  0.9424903271192402
# Testing accuracy score:  0.9347826086956522
# c:\Users\megha\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ## Support vector machines

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(x_train, y_train)
print("Training accuracy score: ", svc.score(x_train, y_train))
print("Testing accuracy score: ", svc.score(x_test, y_test))
# Out:
# Training accuracy score:  0.9873373197326768
# Testing accuracy score:  0.9819524200164069

# %% [markdown]
# ## K nearest neighbours

# %%
from sklearn.neighbors import KNeighborsClassifier
kc = KNeighborsClassifier()
kc.fit(x_train, y_train)
print("Training accuracy score: ", kc.score(x_train, y_train))
print("Testing accuracy score: ", kc.score(x_test, y_test))
# Out:
# Training accuracy score:  0.9994723883221949
# Testing accuracy score:  0.9983593109105825

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x_train, y_train)
print("Training accuracy score: ", rfc.score(x_train, y_train))
print("Testing accuracy score: ", rfc.score(x_test, y_test))
# Out:
# Training accuracy score:  1.0
# Testing accuracy score:  1.0

# %%
acc = pd.DataFrame({
    "Model": ['Logistic Regression', "Support Vector Classifier", "K Neighbour Classifier", "Random Forest Classifier"],
    "Training Accuracy": [lr.score(x_train, y_train), svc.score(x_train, y_train), kc.score(x_train, y_train), rfc.score(x_train, y_train)],
    "Testing Accuracy": [lr.score(x_test, y_test), svc.score(x_test, y_test), kc.score(x_test, y_test), rfc.score(x_test, y_test)]
})
acc.head()
# Out:
#                        Model  Training Accuracy  Testing Accuracy
# 0        Logistic Regression           0.942490          0.934783
# 1  Support Vector Classifier           0.987337          0.981952
# 2     K Neighbour Classifier           0.999472          0.998359
# 3   Random Forest Classifier           1.000000          1.000000

# %%
acc.groupby("Model").sum().plot(kind='bar', legend=True, grid=True, figsize = (8, 5), colormap = "Set2")
# Out:
# <AxesSubplot: xlabel='Model'>

# %% [markdown]
# # We can see that no model has overfitten or underfitten
# # Random Forest has given perfect accuracy on training and testing data
# # Other models have also performed very well
